# %%
# Import necessary libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
#  ## URL: [UK Road Safety Dataset (1979-2020)](https://www.kaggle.com/datasets/keithcooper/uk-road-safety-dataset-1979-2020?select=dft-road-casualty-statistics-casualty-1979-2020.csv)
#
#
# # Data subset 2016-2020

# %%
# Load the data into a data frame
data = pd.read_csv('dft-road-casualty-statistics-accident-1979-2020.csv')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17540\2803594989.py:2: DtypeWarning: Columns (0,2,15,16,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('dft-road-casualty-statistics-accident-1979-2020.csv')

# %%
data.head()
# Out:
#   accident_index  accident_year accident_reference  location_easting_osgr  \
# 0  197901A11AD14           1979          01A11AD14                    NaN
# 1  197901A1BAW34           1979          01A1BAW34               198460.0
# 2  197901A1BFD77           1979          01A1BFD77               406380.0
# 3  197901A1BGC20           1979          01A1BGC20               281680.0
# 4  197901A1BGF95           1979          01A1BGF95               153960.0
#
#    location_northing_osgr  longitude  latitude  police_force  \
# 0                     NaN        NaN       NaN             1
# 1                894000.0        NaN       NaN             1
# 2                307000.0        NaN       NaN             1
# 3                440000.0        NaN       NaN             1
# 4                795000.0        NaN       NaN             1
#
#    accident_severity  number_of_vehicles  ...  \
# 0                  3                   2  ...
# 1                  3                   1  ...
# ...

# %%
data.shape
# Out:
# (8602824, 36)

# %%
sub_data = data[(data['accident_year'] >= 2016) & (data['accident_year'] <= 2020)]

# %%
sub_data.shape
# Out:
# (597973, 36)

# %%
# Specify the file path using a raw string
path = r'C:\Users\Hp\Desktop\python\Data Mining\Assignment 2'

# Save the DataFrame to a CSV file
sub_data.to_csv(path + '\\UKRoad_Accident.csv', index=False)
